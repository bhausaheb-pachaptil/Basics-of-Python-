# %% [markdown]
# <a href="https://colab.research.google.com/github/bhausaheb-pachaptil/Basics-of-Python-/blob/main/BasicTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread("/content/img1.jpg")
im_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %% [markdown]
# **Gray Scale Conversion**

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')
#plt.title("Gray Scale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# **Image Resizing**

# %%
resized=cv2.resize(img,(200,300))
plt.imshow(cv2.cvtColor(resized,cv2.COLOR_BGR2RGB))
plt.title("Image Resize")
plt.axis("off")
plt.show()

# %% [markdown]
# **Image Filtering (Blurring)**

# %%
blur=cv2.GaussianBlur(img,(7,7),0)
plt.imshow(cv2.cvtColor(blur,cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Blured Image")
plt.show()

# %% [markdown]
# **Edge Detection (Canny)**

# %%
Edge=cv2.Canny(img,100,200)
plt.imshow(Edge,cmap='gray')
plt.axis("off")
plt.title("Edge Detection")
plt.show()

# %% [markdown]
# **Thresholding (Black & White Conversion)**

# %%
_, thresh=cv2.threshold(gray,125,255,cv2.THRESH_BINARY)
plt.imshow(thresh,cmap='gray')
plt.axis("off")
plt.title("Binary Threshold")
plt.show()
